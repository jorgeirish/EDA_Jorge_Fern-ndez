# %%
# %pip install xlrd
# Out:
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importamos librerias
from bs4 import BeautifulSoup as bs
import lxml
import requests
import zipfile
import pandas as pd
import numpy as np
import json
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris, load_boston

# %%
#url1 = ("https://www.ine.es/jaxiT3/dlgExport.htm?t=37670&L=0&nocab=1")
gasto = pd.read_csv("Tri_Distribucion_gasto-CCAA_segun_pais.csv", sep=";", index_col="Periodo")
gasto.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2392\2128008819.py in <module>
#       1 #url1 = ("https://www.ine.es/jaxiT3/dlgExport.htm?t=37670&L=0&nocab=1")
# ----> 2 gasto = pd.read_csv("Tri_Distribucion_gasto-CCAA_segun_pais.csv", sep=";", index_col="Periodo")
#       3 gasto.head()
#       4
#       5
#
# c:\Users\jorge\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
#http://estadisticas.mecd.gob.es/EducaJaxiPx/Tabla.htm?path=/laborales/epa/form//l0/&file=form_1_02.px&type=pcaxis&L=0
data = pd.read_csv("form_1_02sc.csv", sep=";")
data.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[134], line 2
#       1 #http://estadisticas.mecd.gob.es/EducaJaxiPx/Tabla.htm?path=/laborales/epa/form//l0/&file=form_1_02.px&type=pcaxis&L=0
# ----> 2 data = pd.read_csv("form_1_02sc.csv", sep=";")
#       3 data.head()
#
# File c:\Users\jorge\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\jorge\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
# ...

# %%
data2 = pd.read_excel("form_1_02.xls")
data2.head(20)
# Out:
#     EXPLOTACIÓN DE LAS VARIABLES EDUCATIVAS DE LA ENCUESTA DE POBLACIÓN ACTIVA / NIVEL DE FORMACIÓN Y ESTATUS LABORAL  \
# 0                                           Actividad
# 1                                                 NaN
# 2   1.2. Tasas de actividad de la población de 25-...
# 3                  Unidades:  Porcentajes de personas
# 4                                                 NaN
# 5
# 6
# 7
# 8                                        25 - 64 años
# 9                                               TOTAL
# 10                                          Andalucía
# 11                                             Aragón
# 12                            Asturias, Principado de
# 13                                     Balears, Illes
# 14                                           Canarias
# 15                                          Cantabria
# 16                                    Castilla y León
# 17                                 Castilla-La Mancha
# ...

# %%
url = "https://www.juntadeandalucia.es/institutodeestadisticaycartografia/movilidad/descarga/Desplazamientos_distribucion_horaria.zip"
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
# Guardamos el zip
filename = "movilidad_AND.zip"
with open(filename, "wb") as f:
    f.write(r.content)

# %%
# Extraemos lo que hay dentro
with zipfile.ZipFile(filename, "r") as zip_ref:
    zip_ref.extractall("")

# %%
# Leemos los datos
desplazamientos = pd.read_csv("Desplazamientos_distribucion_horaria.csv")
desplazamientos.tail(10)
# Out:
#              fecha  prov_origen  prov_destino  periodo  Dia_Sem  \
# 772498  2021-05-09           99            41       14        1
# 772499  2021-05-09           99            41       15        1
# 772500  2021-05-09           99            41       16        1
# 772501  2021-05-09           99            41       17        1
# 772502  2021-05-09           99            41       18        1
# 772503  2021-05-09           99            41       19        1
# 772504  2021-05-09           99            41       20        1
# 772505  2021-05-09           99            41       21        1
# 772506  2021-05-09           99            41       22        1
# 772507  2021-05-09           99            41       23        1
#
#         desplazamientos
# 772498          691.343
# 772499          947.914
# 772500         1087.657
# 772501          989.286
# 772502         1015.412
# 772503          755.519
# 772504          611.947
# 772505          328.527
# 772506          351.414
# ...

# %%
personas = pd.read_csv("Personas_desplazan.csv")
personas.head(10)
# Out:
#         Fecha  Provincia  Total_personas   Mov_activa  Porc_mov_activos  \
# 0  2020-02-14          4      707100.008   507855.435              71.8
# 1  2020-02-14         11     1239301.865   914811.809              73.8
# 2  2020-02-14         14      789366.716   578584.828              73.3
# 3  2020-02-14         18      918897.667   666977.155              72.6
# 4  2020-02-14         21      521310.358   352299.978              67.6
# 5  2020-02-14         23      644885.196   427663.497              66.3
# 6  2020-02-14         29     1640008.634  1225827.717              74.7
# 7  2020-02-14         41     1932139.802  1433184.721              74.2
# 8  2020-02-15          4      707753.273   472590.383              66.8
# 9  2020-02-15         11     1253072.371   873006.988              69.7
#
#                       Fase
# 0  A Periodo de referencia
# 1  A Periodo de referencia
# 2  A Periodo de referencia
# 3  A Periodo de referencia
# 4  A Periodo de referencia
# ...

# %%
url_JA = "https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/2022/"
response = requests.get(url_JA)
html = response.content

soup = bs(html, "lxml")
all_a = soup.find_all('a')

# %%
all_a
# Out:
# [<a href="https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/"> Parent Directory</a>,
#  <a href="https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/2022/AL_20220101.csv"> AL_20220101.csv</a>,
#  <a href="https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/2022/AL_20220102.csv"> AL_20220102.csv</a>,
#  <a href="https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/2022/AL_20220103.csv"> AL_20220103.csv</a>,
#  <a href="https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/2022/AL_20220104.csv"> AL_20220104.csv</a>,
#  <a href="https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/2022/AL_20220105.csv"> AL_20220105.csv</a>,
#  <a href="https://www.juntadeandalucia.es/medioambiente/atmosfera/informes_siva/cuantitativo/2022/AL_20220106.csv"> AL_20220106.csv</a>,
# ...

# %%
ejemplo = pd.read_csv("AL_20220101.csv", sep=";")
ejemplo.tail()
# Out:
#                                            D_PROVINCIA  \
# 307  ALMERIA                                       ...
# 308  ALMERIA                                       ...
# 309  ALMERIA                                       ...
# 310  ALMERIA                                       ...
# 311  ALMERIA                                       ...
#
#                                            D_MUNICIPIO  \
# 307  MOJÁCAR                                       ...
# 308  NÍJAR                                         ...
# 309  NÍJAR                                         ...
# 310  NÍJAR                                         ...
# 311  NÍJAR                                         ...
#
#                                             D_ESTACION  \
# 307  MOJÁCAR                                       ...
# 308  FERNÁN PÉREZ                                  ...
# 309  LA GRANATILLA                                 ...
# 310  LA JOYA                                       ...
# ...
